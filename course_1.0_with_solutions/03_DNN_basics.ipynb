# %% [markdown]
# # DNN: the Basics
#
# In this notebook, we will learn the basics of a Deep Neural Network (DNN) based on [Keras](https://keras.io/), a high-level API for building and training deep learning models, running on top of [TensorFlow](https://www.tensorflow.org/), an open source platform for machine learning.
#
# We will use the `fashion-mnist` dataset, which is useful for quick examples when learning the basics. In [03_DNN_practical.ipynb](03_DNN_practical.ipynb), we will follow the same principles to practice with a more relevant scientific dataset. To understand how a DNN works, we will implement a fully connected DNN from scratch in [03_DNN_start_from_scratch.ipynb](03_DNN_start_from_scratch.ipynb),

# %%
# tensorflow
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout

# check version
print('Using TensorFlow v%s' % tf.__version__)
acc_str = 'accuracy' if tf.__version__[:2] == '2.' else 'acc'

# helpers
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# Out:
# Using TensorFlow v2.3.0

# %% [markdown]
# ---

# %% [markdown]
# # The dataset
#
# To start with, we load the `fashion-mnist` dataset from Keras:

# %%
# load dataset
fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# normalise images
train_images = train_images / 255.0
test_images = test_images / 255.0

# string labels
string_labels = ['T-shirt', 'Trouser', 'Pullover', 'Dress', 'Coat',
                 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# print info
print("Number of training data: %d" % len(train_labels))
print("Number of test data: %d" % len(test_labels))
print("Image pixels: %s" % str(train_images[0].shape))
print("Number of classes: %d" % (np.max(train_labels) + 1))
# Out:
# Number of training data: 60000
# Number of test data: 10000
# Image pixels: (28, 28)
# Number of classes: 10

# %% [markdown]
# We can randomly plot some images and their labels:

# %%
# function to plot an image in a subplot
def subplot_image(image, label, nrows=1, ncols=1, iplot=0, label2='', label2_color='r'):
    plt.subplot(nrows, ncols, iplot + 1)
    plt.imshow(image, cmap=plt.cm.binary)
    plt.xlabel(label, c='k', fontsize=12)
    plt.title(label2, c=label2_color, fontsize=12, y=-0.33)
    plt.xticks([])
    plt.yticks([])
    
# ramdomly plot some images and their labels
nrows = 4
ncols = 8
plt.figure(dpi=100, figsize=(ncols * 2, nrows * 2.2))
for iplot, idata in enumerate(np.random.choice(len(train_labels), nrows * ncols)):
    label = "%d: %s" % (train_labels[idata], string_labels[train_labels[idata]])
    subplot_image(train_images[idata], label, nrows, ncols, iplot)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Classification by DNN
#
# Here we will create and train a DNN model to classify the images in `fashion-mnist`. With Keras, the task can be divided into three essential steps:
#
# 1. Build the network architecture;
# 2. Compile the model;
# 3. Train the model.
#
# These steps may be repeated for a few times to improve the quality (accuracy and stability) of the model.

# %% [markdown]
# ## 1. Build the network architecture
#
# Our first DNN will be a simple multi-layer perceptron with only one hidden layer, as shown in the following figure:
#
#
# ![dense.jpeg](https://i.ibb.co/0yrVL28/dnn.png)
#
#
#
# In general, a network of this kind should include an input layer, some hidden layers and an output layer. In this example, all the layers will be `Dense` layers.
#
#
# ### The input layer
#
# We first need to determine the dimensionality of the input layer. In this case, we flatten (using a `Flatten` layer) the images and feed them to the network. As the images are 28 $\times$ 28 in pixels, the input size will be 784.
#
#
# ### The hidden layers
#
# We use one hidden layer in this case and use `ReLU` as its activation function:
#
# > $R(x)=\max(0,x)$
#
# **NOTE**: Different activation functions are used for different tasks. Remember that `ReLU` generally performs well for training a network, but it can *only* be used in the hidden layers.
#
#
# ### The output layer
#
# We usually encode categorical data as a "one-hot" vector. In this case, we have a vector of length 10 on the output side, where each element corresponds to a class of apparel. Ideally, we hope the values to be either 1 or 0, with 1 for the correct class and 0 for the others, so we use `sigmoid` as the activation function for the output layer:
#
# > $S(x) = \dfrac{1}{1 + e^{-x}}$

# %%
# build the network architecture
model = Sequential()
model.add(Flatten(input_shape=(28, 28)))
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='sigmoid'))

# %% [markdown]
# We can take a look at the summary of the model using `model.summary()`. The number of trainable parameters of a layer = $P\times N+N$, where $P$ is the size of its precedent layer and $N$ its own size. Here $P\times N$ accounts for the weights of the $P\times N$ connections and $N$ for the biases of this layer.

# %%
# print summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 2. Compile the model
#
# Next, we need to compile our model. This is where we specify all sorts of hyperparameters associated with the model. Here are the most important ones:
#
# ### Loss
#
# The loss is the objective function to be minimised during training. Gradients of the loss with respect to the model parameters, calculated by backpropagating the errors, determine the direction to update the model parameters. Follow [03_DNN_start_from_scratch.ipynb](03_DNN_start_from_scratch.ipynb) to learn the details about *backpropagation* and *gradient descent*. In this case, we will use `SparseCategoricalCrossentropy` as the loss. The term *sparse* means that the output vector is sparse, with many more zeros than ones in the one-hot encoding.
#
#
# ### Optimiser
#
# An optimiser is an algorithm determining how the model parameters are updated based on the loss. One critical hyperparameter for the optimiser is the *learning rate*, which determines the magnitude to update the model parameters (also see [03_DNN_start_from_scratch.ipynb](03_DNN_start_from_scratch.ipynb) for details). In many applications, *Adam* is usually a good choice at the beginning. We will use Adam in this example.
#
#
# ### Metric
#
# The metrics do not affect the training result but monitor the training process to give us a sense of how well the model is improving after seeing more data. We can also use them to choose between models at the end. In our case, we will monitor the `accuracy`.

# %%
# compile the model
model.compile(optimizer='adam',
              loss=keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# %% [markdown]
# ## 3. Train the model
#
# Now we can start to train the model with `fashion-mnist`. This is done by calling the `model.fit()` method, where we need to specify a few more parameters:
#
# ### Epochs
#
# It is the number of times that the model will run through the entire dataset during training.
#
#
# ### Batch size
#
# It determines how many data will be used at a time to determine the gradient used for parameter update. Follow [03_DNN_start_from_scratch.ipynb](03_DNN_start_from_scratch.ipynb) to learn more about *Batch*, *Mini-batch* and *Stochastic Gradient Descent*.
#
#
# ### Validation data
# Accuracy and loss can be computed and logged with a validation dataset passed to `model.fit()`. To make predictions with a confidence equivalent to that for training, the accuracy for the validation data should not differ too much from that for the training data.

# %%
# train the model
training_history = model.fit(train_images, train_labels, epochs=50, batch_size=32, 
                             validation_data=(test_images, test_labels))
# Out:
# Epoch 1/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5210 - accuracy: 0.8185 - val_loss: 0.4608 - val_accuracy: 0.8386
# Epoch 2/50
# 1875/1875 [==============================] - 2s 868us/step - loss: 0.3906 - accuracy: 0.8601 - val_loss: 0.3956 - val_accuracy: 0.8616
# Epoch 3/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3481 - accuracy: 0.8743 - val_loss: 0.3779 - val_accuracy: 0.8643
# Epoch 4/50
# 1875/1875 [==============================] - 2s 874us/step - loss: 0.3217 - accuracy: 0.8828 - val_loss: 0.4010 - val_accuracy: 0.8515
# Epoch 5/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3020 - accuracy: 0.8892 - val_loss: 0.3474 - val_accuracy: 0.8741
# Epoch 6/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2881 - accuracy: 0.8948 - val_loss: 0.3361 - val_accuracy: 0.8795
# Epoch 7/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2716 - accuracy: 0.8997 - val_loss: 0.3458 - val_accuracy: 0.8754
# Epoch 8/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2617 - accuracy: 0.9029 - val_loss: 0.3483 - val_accuracy: 0.8783
# Epoch 9/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2533 - accuracy: 0.9051 - val_loss: 0.3453 - val_accuracy: 0.8769
# Epoch 10/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2447 - accuracy: 0.9093 - val_loss: 0.3439 - val_accuracy: 0.8813
# Epoch 11/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2367 - accuracy: 0.9121 - val_loss: 0.3379 - val_accuracy: 0.8830
# Epoch 12/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2270 - accuracy: 0.9154 - val_loss: 0.3427 - val_accuracy: 0.8838
# Epoch 13/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2217 - accuracy: 0.9177 - val_loss: 0.3256 - val_accuracy: 0.8866
# Epoch 14/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2167 - accuracy: 0.9194 - val_loss: 0.3393 - val_accuracy: 0.8824
# Epoch 15/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2102 - accuracy: 0.9210 - val_loss: 0.3472 - val_accuracy: 0.8808
# Epoch 16/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2045 - accuracy: 0.9245 - val_loss: 0.3433 - val_accuracy: 0.8857
# Epoch 17/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1988 - accuracy: 0.9253 - val_loss: 0.3478 - val_accuracy: 0.8850
# Epoch 18/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1950 - accuracy: 0.9272 - val_loss: 0.3451 - val_accuracy: 0.8869
# Epoch 19/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1881 - accuracy: 0.9287 - val_loss: 0.3521 - val_accuracy: 0.8837
# Epoch 20/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1828 - accuracy: 0.9305 - val_loss: 0.3437 - val_accuracy: 0.8869
# Epoch 21/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1805 - accuracy: 0.9327 - val_loss: 0.3414 - val_accuracy: 0.8889
# Epoch 22/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1753 - accuracy: 0.9346 - val_loss: 0.3667 - val_accuracy: 0.8888
# Epoch 23/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1732 - accuracy: 0.9362 - val_loss: 0.3910 - val_accuracy: 0.8806
# Epoch 24/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1689 - accuracy: 0.9372 - val_loss: 0.3685 - val_accuracy: 0.8860
# Epoch 25/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1664 - accuracy: 0.9371 - val_loss: 0.3691 - val_accuracy: 0.8869
# Epoch 26/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1631 - accuracy: 0.9397 - val_loss: 0.3827 - val_accuracy: 0.8835
# Epoch 27/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1579 - accuracy: 0.9407 - val_loss: 0.3771 - val_accuracy: 0.8829
# Epoch 28/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1547 - accuracy: 0.9414 - val_loss: 0.3675 - val_accuracy: 0.8896s: 0.1554 - accuracy: 0. - ETA: 0s - loss: 0.1552 - accuracy: 0.
# Epoch 29/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1546 - accuracy: 0.9419 - val_loss: 0.3942 - val_accuracy: 0.8831
# Epoch 30/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1487 - accuracy: 0.9441 - val_loss: 0.3795 - val_accuracy: 0.8889
# Epoch 31/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1452 - accuracy: 0.9451 - val_loss: 0.3820 - val_accuracy: 0.8868
# Epoch 32/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1450 - accuracy: 0.9454 - val_loss: 0.4251 - val_accuracy: 0.8830
# Epoch 33/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1397 - accuracy: 0.9471 - val_loss: 0.3895 - val_accuracy: 0.8880
# Epoch 34/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1403 - accuracy: 0.9482 - val_loss: 0.4094 - val_accuracy: 0.8875
# Epoch 35/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1348 - accuracy: 0.9496 - val_loss: 0.3960 - val_accuracy: 0.8888
# Epoch 36/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1332 - accuracy: 0.9498 - val_loss: 0.3962 - val_accuracy: 0.8881
# Epoch 37/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1287 - accuracy: 0.9509 - val_loss: 0.4077 - val_accuracy: 0.8874
# Epoch 38/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1291 - accuracy: 0.9505 - val_loss: 0.4126 - val_accuracy: 0.8872
# Epoch 39/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1262 - accuracy: 0.9523 - val_loss: 0.4281 - val_accuracy: 0.8872
# Epoch 40/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1230 - accuracy: 0.9524 - val_loss: 0.4164 - val_accuracy: 0.8863
# Epoch 41/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1225 - accuracy: 0.9532 - val_loss: 0.4285 - val_accuracy: 0.8850
# Epoch 42/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1180 - accuracy: 0.9555 - val_loss: 0.4187 - val_accuracy: 0.8915
# Epoch 43/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1192 - accuracy: 0.9545 - val_loss: 0.4329 - val_accuracy: 0.8845
# Epoch 44/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1158 - accuracy: 0.9555 - val_loss: 0.4684 - val_accuracy: 0.8825
# Epoch 45/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1157 - accuracy: 0.9565 - val_loss: 0.4348 - val_accuracy: 0.8868
# Epoch 46/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1127 - accuracy: 0.9574 - val_loss: 0.4416 - val_accuracy: 0.8847
# Epoch 47/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1108 - accuracy: 0.9578 - val_loss: 0.4511 - val_accuracy: 0.8874
# Epoch 48/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1090 - accuracy: 0.9579 - val_loss: 0.4419 - val_accuracy: 0.8871
# Epoch 49/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1071 - accuracy: 0.9594 - val_loss: 0.4823 - val_accuracy: 0.8853
# Epoch 50/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1069 - accuracy: 0.9597 - val_loss: 0.4709 - val_accuracy: 0.8804

# %% [markdown]
# ### Check training history
#
# We can examine the training history by plotting accuracy and loss against epoch for both the training and the test data.
#
# Notice that the accuracies for the training and the test data diverge as the model trains. This is a classic symptom of [overfitting](https://en.wikipedia.org/wiki/Overfitting), that is, our model corresponds too closely to the training data so that it cannot fit the test data with an equivalent accuracy.

# %%
# plot accuracy
plt.figure(dpi=100, figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(training_history.history[acc_str], label='Accuracy on training data')
plt.plot(training_history.history['val_' + acc_str], label='Accuracy on test data')
plt.legend()
plt.title("Accuracy")

# plot loss
plt.subplot(1, 2, 2)
plt.plot(training_history.history['loss'], label='Loss on training data')
plt.plot(training_history.history['val_loss'], label='Loss on test data')
plt.legend()
plt.title("Loss")
plt.show()

# %% [markdown]
# ## 4. Rgularise and re-train
#
# Dropout, also called dilution, is a regularisation technique to mitigate against overfitting by randomly omitting a certain amount of neurons from a layer. Here we will rebuild our model with `Dropout` between the hidden and the output layers. Let us see whether this can negate the overfitting or not.

# %%
# build the network architecture
model_reg = Sequential()
model_reg.add(Flatten(input_shape=(28, 28)))
model_reg.add(Dense(128, activation='relu'))
model_reg.add(Dropout(0.4))
model_reg.add(Dense(10, activation='sigmoid'))

# compile the model
model_reg.compile(optimizer='adam',
                  loss=keras.losses.SparseCategoricalCrossentropy(),
                  metrics=['accuracy'])

# %%
# train the model
training_history_reg = model_reg.fit(train_images, train_labels, epochs=50, batch_size=32, 
                                     validation_data=(test_images, test_labels))
# Out:
# Epoch 1/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.6311 - accuracy: 0.7778 - val_loss: 0.4495 - val_accuracy: 0.8377
# Epoch 2/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4519 - accuracy: 0.8366 - val_loss: 0.4193 - val_accuracy: 0.8475
# Epoch 3/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4157 - accuracy: 0.8490 - val_loss: 0.3920 - val_accuracy: 0.8563
# Epoch 4/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3968 - accuracy: 0.8553 - val_loss: 0.3882 - val_accuracy: 0.8588
# Epoch 5/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3808 - accuracy: 0.8609 - val_loss: 0.3775 - val_accuracy: 0.8637
# Epoch 6/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3699 - accuracy: 0.8652 - val_loss: 0.3670 - val_accuracy: 0.8647
# Epoch 7/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3592 - accuracy: 0.8675 - val_loss: 0.3748 - val_accuracy: 0.8643
# Epoch 8/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3489 - accuracy: 0.8719 - val_loss: 0.3533 - val_accuracy: 0.8758
# Epoch 9/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3421 - accuracy: 0.8745 - val_loss: 0.3501 - val_accuracy: 0.8748
# Epoch 10/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3354 - accuracy: 0.8759 - val_loss: 0.3613 - val_accuracy: 0.8695
# Epoch 11/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3354 - accuracy: 0.8761 - val_loss: 0.3462 - val_accuracy: 0.8770
# Epoch 12/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3237 - accuracy: 0.8809 - val_loss: 0.3489 - val_accuracy: 0.8737
# Epoch 13/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3214 - accuracy: 0.8801 - val_loss: 0.3488 - val_accuracy: 0.8756
# Epoch 14/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3171 - accuracy: 0.8819 - val_loss: 0.3506 - val_accuracy: 0.8729
# Epoch 15/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3142 - accuracy: 0.8831 - val_loss: 0.3440 - val_accuracy: 0.8785
# Epoch 16/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3110 - accuracy: 0.8841 - val_loss: 0.3377 - val_accuracy: 0.8783accura
# Epoch 17/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3073 - accuracy: 0.8850 - val_loss: 0.3386 - val_accuracy: 0.8784
# Epoch 18/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3053 - accuracy: 0.8855 - val_loss: 0.3495 - val_accuracy: 0.8809
# Epoch 19/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2989 - accuracy: 0.8879 - val_loss: 0.3377 - val_accuracy: 0.8815
# Epoch 20/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3001 - accuracy: 0.8887 - val_loss: 0.3408 - val_accuracy: 0.8814
# Epoch 21/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2948 - accuracy: 0.8907 - val_loss: 0.3396 - val_accuracy: 0.8783
# Epoch 22/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2909 - accuracy: 0.8905 - val_loss: 0.3429 - val_accuracy: 0.8816
# Epoch 23/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2884 - accuracy: 0.8907 - val_loss: 0.3447 - val_accuracy: 0.8797
# Epoch 24/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2860 - accuracy: 0.8916 - val_loss: 0.3339 - val_accuracy: 0.8843
# Epoch 25/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2862 - accuracy: 0.8914 - val_loss: 0.3456 - val_accuracy: 0.8819
# Epoch 26/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2839 - accuracy: 0.8936 - val_loss: 0.3574 - val_accuracy: 0.8782
# Epoch 27/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2812 - accuracy: 0.8928 - val_loss: 0.3547 - val_accuracy: 0.8840
# Epoch 28/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2791 - accuracy: 0.8956 - val_loss: 0.3646 - val_accuracy: 0.8727
# Epoch 29/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2745 - accuracy: 0.8969 - val_loss: 0.3368 - val_accuracy: 0.8839
# Epoch 30/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2739 - accuracy: 0.8967 - val_loss: 0.3490 - val_accuracy: 0.8832
# Epoch 31/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2742 - accuracy: 0.8977 - val_loss: 0.3389 - val_accuracy: 0.8830
# Epoch 32/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2685 - accuracy: 0.8975 - val_loss: 0.3490 - val_accuracy: 0.8829
# Epoch 33/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2689 - accuracy: 0.8985 - val_loss: 0.3571 - val_accuracy: 0.8828
# Epoch 34/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2694 - accuracy: 0.8979 - val_loss: 0.3404 - val_accuracy: 0.8846
# Epoch 35/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2648 - accuracy: 0.8990 - val_loss: 0.3464 - val_accuracy: 0.8876
# Epoch 36/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2635 - accuracy: 0.8995 - val_loss: 0.3453 - val_accuracy: 0.8832
# Epoch 37/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2632 - accuracy: 0.9018 - val_loss: 0.3434 - val_accuracy: 0.8851
# Epoch 38/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2600 - accuracy: 0.9016 - val_loss: 0.3593 - val_accuracy: 0.8815
# Epoch 39/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2561 - accuracy: 0.9025 - val_loss: 0.3472 - val_accuracy: 0.8879
# Epoch 40/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2573 - accuracy: 0.9016 - val_loss: 0.3512 - val_accuracy: 0.8851
# Epoch 41/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2552 - accuracy: 0.9033 - val_loss: 0.3459 - val_accuracy: 0.8853
# Epoch 42/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2541 - accuracy: 0.9018 - val_loss: 0.3457 - val_accuracy: 0.88731s
# Epoch 43/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2520 - accuracy: 0.9032 - val_loss: 0.3757 - val_accuracy: 0.8834
# Epoch 44/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2509 - accuracy: 0.9048 - val_loss: 0.3519 - val_accuracy: 0.8865
# Epoch 45/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2503 - accuracy: 0.9053 - val_loss: 0.3575 - val_accuracy: 0.8848
# Epoch 46/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2487 - accuracy: 0.9031 - val_loss: 0.3511 - val_accuracy: 0.8839
# Epoch 47/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2481 - accuracy: 0.9053 - val_loss: 0.3690 - val_accuracy: 0.8836
# Epoch 48/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2469 - accuracy: 0.9060 - val_loss: 0.3648 - val_accuracy: 0.8852
# Epoch 49/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2434 - accuracy: 0.9060 - val_loss: 0.3530 - val_accuracy: 0.8867
# Epoch 50/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2446 - accuracy: 0.9062 - val_loss: 0.3526 - val_accuracy: 0.8861

# %%
# plot accuracy
plt.figure(dpi=100, figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(training_history_reg.history[acc_str], label='Accuracy on training data')
plt.plot(training_history_reg.history['val_' + acc_str], label='Accuracy on test data')
plt.plot(training_history.history['val_' + acc_str], label='Accuracy on test data (no dropout)')
plt.legend()
plt.title("Accuracy")

# plot loss
plt.subplot(1, 2, 2)
plt.plot(training_history_reg.history['loss'], label='Loss on training data')
plt.plot(training_history_reg.history['val_loss'], label='Loss on test data')
plt.plot(training_history.history['val_loss'], label='Loss on test data (no dropout)')
plt.legend()
plt.title("Loss")
plt.show()

# %% [markdown]
# ## 5. Make predictions
#
# Finally, we can use our trained model to make predictions. Here we show some wrong predictions for the test data, from which we may get some ideas about what kinds of images baffle our model.

# %%
# use test images to make predictions
pred_lables = model_reg.predict(test_images).argmax(axis=1)

# %%
# get the indices of wrong predictions
id_wrong = np.where(pred_lables != test_labels)[0]
print("Number of test data: %d" % test_labels.size)
print("Number of wrong predictions: %d" % id_wrong.size)

# plot the wrong predictions
nrows = 4
ncols = 8
plt.figure(dpi=100, figsize=(ncols * 2, nrows * 2.2))
for iplot, idata in enumerate(np.random.choice(id_wrong, nrows * ncols)):
    label = "%d: %s" % (test_labels[idata], string_labels[test_labels[idata]])
    label2 = "%d: %s" % (pred_lables[idata], string_labels[pred_lables[idata]])
    subplot_image(test_images[idata], label, nrows, ncols, iplot, label2, 'r')
plt.show()
# Out:
# Number of test data: 10000
# Number of wrong predictions: 1139

# %% [markdown]
# ---

# %% [markdown]
# ## Exercises
#
# * Change some hyperparameters in `model.compile()` and `model.fit()` to see their effects (see reference of [tf.keras.Model](https://www.tensorflow.org/api_docs/python/tf/keras/Model));
# * Use two hidden layers (with dropout), e.g., respectively with sizes 256 and 64, and see whether the accuracy can be improved or not;
# * Change the output from 0-1 binary to probability, i.e., the one-hot vector represents the probabilities that an image belongs to the classes; this can be achieved by 1) removing `activation='sigmoid'` from the output layer and 2) appending a `Softmax` layer after the trained model, e.g.,
# ```python
# probability_model = Sequential([model_reg, keras.layers.Softmax()])
# ```
