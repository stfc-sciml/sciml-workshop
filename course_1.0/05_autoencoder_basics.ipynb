# %% [markdown]
# # Autoencoder: the Basics
#
# An autoencoder is a type of artificial neural network used to learn efficient data codings in an unsupervised manner. The aim of an autoencoder is to learn a representation (encoding) for a set of data, typically for dimensionality reduction, by training the network to ignore signal "noise". Along with the reduction side, a reconstructing side is learnt, where the autoencoder tries to generate from the reduced encoding a representation as close as possible to its original input, hence its name. -- from [Wikipedia](https://en.wikipedia.org/wiki/Autoencoder)
#
# An autoencoder can be used for
#
# * feature analysis and dimensionality reduction
# * denoising
# * generating artificial contents (such as faces, musics, scenes)
#
#
#
# ![autoencoder.jpg](https://i.ibb.co/wL242Gy/vaee.png)
#
#
# In this notebook, we will use an autoencoder in two different ways:
#
# * **Semi-supervised**: train an autoencoder using images from one specific class in the `fashion-mnist` dataset; the trained autoencoder can then be used to decide whether an image belongs to this class based on the reconstruction error; the autoencoder can also be used to generate new images of that class by changing the *features* in the latent space (the bottleneck);
#
# * **Unsupervised**: train an autoencoder using all images in `fashion-mnist` and cluster the images based on the features.

# %%
# tensorflow
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Reshape, Input

# check version
print('Using TensorFlow v%s' % tf.__version__)
acc_str = 'accuracy' if tf.__version__[:2] == '2.' else 'acc'

# k-means
from sklearn.cluster import KMeans
from sklearn import metrics

# helpers
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# widgets for dynamic controls
import ipywidgets as widgets
# Out:
# Using TensorFlow v2.3.0

# %% [markdown]
# ---

# %% [markdown]
# # The Dataset
#
# We start by loading the `fashion-mnist` dataset.

# %%
# load dataset
fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# normalise images
train_images = train_images / 255.0
test_images = test_images / 255.0

# string labels
string_labels = ['T-shirt', 'Trouser', 'Pullover', 'Dress', 'Coat',
                 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# print info
print("Number of training data: %d" % len(train_labels))
print("Number of test data: %d" % len(test_labels))
print("Image pixels: %s" % str(train_images[0].shape))
print("Number of classes: %d" % (np.max(train_labels) + 1))
# Out:
# Number of training data: 60000
# Number of test data: 10000
# Image pixels: (28, 28)
# Number of classes: 10

# %%
# function to plot an image in a subplot
def subplot_image(image, label, nrows=1, ncols=1, iplot=0, label2='', label2_color='r'):
    plt.subplot(nrows, ncols, iplot + 1)
    plt.imshow(image, cmap=plt.cm.binary)
    plt.xlabel(label, c='k', fontsize=12)
    plt.title(label2, c=label2_color, fontsize=12, y=-0.33)
    plt.xticks([])
    plt.yticks([])
    
# ramdomly plot some images and their labels
nrows = 4
ncols = 8
plt.figure(dpi=100, figsize=(ncols * 2, nrows * 2.2))
for iplot, idata in enumerate(np.random.choice(len(train_labels), nrows * ncols)):
    label = "%d: %s" % (train_labels[idata], string_labels[train_labels[idata]])
    subplot_image(train_images[idata], label, nrows, ncols, iplot)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Semi-supervised
#
# In this part, we will train an autoencoder using one specific class in `fashion-mnist`. The autoencoder will use the images from this class as **both the input and the output**. After training the autoencoder, we can feed in any image to decide whether it belongs to this class based on whether it can be well reconstructed by the autoencoder.
#
# Such a strategy can be useful when
#
# * only one or a few classes in the dataset can be reliably labelled;
# * no data in the dataset can be reliably labelled but we can generate synthetic data for some specific classes.
#
# Besides, the autoencoder can be used to generate new images of that class by changing the **features** in the latent space (the bottleneck).

# %% [markdown]
# ## 1. Choose a target class
#
# First, we choose a target class for training and extract the corresponding image subsets.

# %%
###############################
# choose a target class below #
###############################
# 'T-shirt', 'Trouser', 'Pullover', 'Dress', 'Coat',
# 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot'
target_class = 'Sneaker'

# get image subset of the chosen class
target_label = string_labels.index(target_class)
target_train_images = train_images[np.where(train_labels == target_label)[0]]
target_test_images = test_images[np.where(test_labels == target_label)[0]]
print('Number of images labelled "%s":' % (target_class,))
print('%d in training data' % (target_train_images.shape[0],))
print('%d in test data' % (target_test_images.shape[0],))
# Out:
# Number of images labelled "Sneaker":
# 6000 in training data
# 1000 in test data

# %% [markdown]
# ## 2. Build and train the autoencoder
#
# As shown in the opening figure, an autoencoder contains three parts:
#
# * the encoder
# * the bottleneck
# * the decoder
#
# Here we use three dense layers to implement these parts. The layers in the encoder and the decoder are reciprocal.

# %% [markdown]
# ### Build the autoencoder

# %%
########################################
# specify the size of the latent space #
########################################
nfeature = 8

# build the network architecture
autoencoder = Sequential()

# encoder --------------------------------------------/
autoencoder.add(Flatten(input_shape=(28, 28)))
autoencoder.add(Dense(128, activation='relu'))
# ----------------------------------------------------/

# bottleneck -----------------------------------------/
autoencoder.add(Dense(nfeature, activation='relu'))
# ----------------------------------------------------/

# decoder --------------------------------------------/
autoencoder.add(Dense(128, activation='relu'))
autoencoder.add(Dense(784, activation='sigmoid'))
autoencoder.add(Reshape((28, 28)))
# ----------------------------------------------------/

# print summary
autoencoder.summary()

# compile the model
autoencoder.compile(optimizer='adam', loss='binary_crossentropy', 
                    metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 1032
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               1152
# _________________________________________________________________
# dense_3 (Dense)              (None, 784)               101136
# _________________________________________________________________
# reshape (Reshape)            (None, 28, 28)            0
# =================================================================
# Total params: 203,800
# Trainable params: 203,800
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the autoencoder

# %% [markdown]
# **NOTE**: The input and output images are identical in this case.

# %%
# train the model
training_history = autoencoder.fit(target_train_images, target_train_images,
                                   epochs=100, batch_size=32,
                                   validation_data=(target_test_images, target_test_images))
# Out:
# Epoch 1/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.2718 - accuracy: 0.0447 - val_loss: 0.2246 - val_accuracy: 0.0491
# Epoch 2/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.2198 - accuracy: 0.0509 - val_loss: 0.2129 - val_accuracy: 0.0575
# Epoch 3/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.2112 - accuracy: 0.0557 - val_loss: 0.2090 - val_accuracy: 0.0550
# Epoch 4/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.2058 - accuracy: 0.0567 - val_loss: 0.2036 - val_accuracy: 0.0583
# Epoch 5/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.2021 - accuracy: 0.0623 - val_loss: 0.2012 - val_accuracy: 0.0626
# Epoch 6/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.2005 - accuracy: 0.0659 - val_loss: 0.2002 - val_accuracy: 0.0589
# Epoch 7/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1995 - accuracy: 0.0642 - val_loss: 0.1995 - val_accuracy: 0.0686
# Epoch 8/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1987 - accuracy: 0.0651 - val_loss: 0.1987 - val_accuracy: 0.0671
# Epoch 9/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1983 - accuracy: 0.0679 - val_loss: 0.1982 - val_accuracy: 0.0700
# Epoch 10/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1979 - accuracy: 0.0708 - val_loss: 0.1980 - val_accuracy: 0.0699
# Epoch 11/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1975 - accuracy: 0.0766 - val_loss: 0.1981 - val_accuracy: 0.0758
# Epoch 12/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1973 - accuracy: 0.0822 - val_loss: 0.1976 - val_accuracy: 0.0921
# Epoch 13/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1970 - accuracy: 0.0952 - val_loss: 0.1972 - val_accuracy: 0.1013
# Epoch 14/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1967 - accuracy: 0.1028 - val_loss: 0.1970 - val_accuracy: 0.1010
# Epoch 15/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1966 - accuracy: 0.1071 - val_loss: 0.1970 - val_accuracy: 0.1091
# Epoch 16/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1964 - accuracy: 0.1096 - val_loss: 0.1968 - val_accuracy: 0.1109
# Epoch 17/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1962 - accuracy: 0.1081 - val_loss: 0.1967 - val_accuracy: 0.1098
# Epoch 18/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1961 - accuracy: 0.1139 - val_loss: 0.1964 - val_accuracy: 0.1151
# Epoch 19/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1960 - accuracy: 0.1060 - val_loss: 0.1964 - val_accuracy: 0.1110
# Epoch 20/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1959 - accuracy: 0.1113 - val_loss: 0.1962 - val_accuracy: 0.1067
# Epoch 21/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1957 - accuracy: 0.1102 - val_loss: 0.1961 - val_accuracy: 0.1140
# Epoch 22/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1956 - accuracy: 0.1096 - val_loss: 0.1959 - val_accuracy: 0.1105
# Epoch 23/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.1955 - accuracy: 0.1104 - val_loss: 0.1961 - val_accuracy: 0.1115
# Epoch 24/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1954 - accuracy: 0.1107 - val_loss: 0.1960 - val_accuracy: 0.1094
# Epoch 25/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1953 - accuracy: 0.1114 - val_loss: 0.1959 - val_accuracy: 0.1139
# Epoch 26/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1953 - accuracy: 0.1144 - val_loss: 0.1958 - val_accuracy: 0.1151
# Epoch 27/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1952 - accuracy: 0.1151 - val_loss: 0.1956 - val_accuracy: 0.1127
# Epoch 28/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1950 - accuracy: 0.1171 - val_loss: 0.1956 - val_accuracy: 0.1142
# Epoch 29/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1950 - accuracy: 0.1148 - val_loss: 0.1957 - val_accuracy: 0.1180
# Epoch 30/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1949 - accuracy: 0.1158 - val_loss: 0.1955 - val_accuracy: 0.1173
# Epoch 31/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1948 - accuracy: 0.1201 - val_loss: 0.1956 - val_accuracy: 0.1179
# Epoch 32/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1948 - accuracy: 0.1174 - val_loss: 0.1955 - val_accuracy: 0.1213
# Epoch 33/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1947 - accuracy: 0.1193 - val_loss: 0.1954 - val_accuracy: 0.1172
# Epoch 34/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1947 - accuracy: 0.1235 - val_loss: 0.1954 - val_accuracy: 0.1211
# Epoch 35/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1946 - accuracy: 0.1209 - val_loss: 0.1954 - val_accuracy: 0.1215
# Epoch 36/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1946 - accuracy: 0.1222 - val_loss: 0.1952 - val_accuracy: 0.1247
# Epoch 37/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1945 - accuracy: 0.1252 - val_loss: 0.1951 - val_accuracy: 0.1256
# Epoch 38/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1944 - accuracy: 0.1249 - val_loss: 0.1953 - val_accuracy: 0.1262
# Epoch 39/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1944 - accuracy: 0.1261 - val_loss: 0.1953 - val_accuracy: 0.1299
# Epoch 40/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1943 - accuracy: 0.1281 - val_loss: 0.1952 - val_accuracy: 0.1241
# Epoch 41/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1943 - accuracy: 0.1289 - val_loss: 0.1952 - val_accuracy: 0.1313
# Epoch 42/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1943 - accuracy: 0.1304 - val_loss: 0.1952 - val_accuracy: 0.1333
# Epoch 43/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1942 - accuracy: 0.1308 - val_loss: 0.1952 - val_accuracy: 0.1328
# Epoch 44/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1941 - accuracy: 0.1325 - val_loss: 0.1951 - val_accuracy: 0.1339
# Epoch 45/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1942 - accuracy: 0.1328 - val_loss: 0.1950 - val_accuracy: 0.1287
# Epoch 46/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1941 - accuracy: 0.1330 - val_loss: 0.1951 - val_accuracy: 0.1351
# Epoch 47/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1940 - accuracy: 0.1337 - val_loss: 0.1950 - val_accuracy: 0.1332
# Epoch 48/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1940 - accuracy: 0.1343 - val_loss: 0.1952 - val_accuracy: 0.1360
# Epoch 49/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1940 - accuracy: 0.1363 - val_loss: 0.1949 - val_accuracy: 0.1370
# Epoch 50/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1939 - accuracy: 0.1374 - val_loss: 0.1951 - val_accuracy: 0.1347
# Epoch 51/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1939 - accuracy: 0.1395 - val_loss: 0.1951 - val_accuracy: 0.1364
# Epoch 52/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1939 - accuracy: 0.1376 - val_loss: 0.1948 - val_accuracy: 0.1365
# Epoch 53/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1938 - accuracy: 0.1399 - val_loss: 0.1948 - val_accuracy: 0.1434
# Epoch 54/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1938 - accuracy: 0.1411 - val_loss: 0.1948 - val_accuracy: 0.1445
# Epoch 55/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1937 - accuracy: 0.1408 - val_loss: 0.1948 - val_accuracy: 0.1456
# Epoch 56/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1937 - accuracy: 0.1431 - val_loss: 0.1948 - val_accuracy: 0.1414
# Epoch 57/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1937 - accuracy: 0.1433 - val_loss: 0.1948 - val_accuracy: 0.1443
# Epoch 58/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1936 - accuracy: 0.1457 - val_loss: 0.1948 - val_accuracy: 0.1411
# Epoch 59/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1936 - accuracy: 0.1450 - val_loss: 0.1948 - val_accuracy: 0.1474
# Epoch 60/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1935 - accuracy: 0.1470 - val_loss: 0.1946 - val_accuracy: 0.1496
# Epoch 61/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1932 - accuracy: 0.1465 - val_loss: 0.1940 - val_accuracy: 0.1458
# Epoch 62/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1926 - accuracy: 0.1464 - val_loss: 0.1936 - val_accuracy: 0.1474
# Epoch 63/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1923 - accuracy: 0.1488 - val_loss: 0.1932 - val_accuracy: 0.1512
# Epoch 64/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1921 - accuracy: 0.1489 - val_loss: 0.1931 - val_accuracy: 0.1460
# Epoch 65/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1919 - accuracy: 0.1501 - val_loss: 0.1931 - val_accuracy: 0.1490
# Epoch 66/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1917 - accuracy: 0.1509 - val_loss: 0.1930 - val_accuracy: 0.1510
# Epoch 67/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1916 - accuracy: 0.1521 - val_loss: 0.1930 - val_accuracy: 0.1499
# Epoch 68/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1915 - accuracy: 0.1545 - val_loss: 0.1929 - val_accuracy: 0.1527
# Epoch 69/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1915 - accuracy: 0.1550 - val_loss: 0.1928 - val_accuracy: 0.1591
# Epoch 70/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1914 - accuracy: 0.1561 - val_loss: 0.1927 - val_accuracy: 0.1567
# Epoch 71/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1913 - accuracy: 0.1570 - val_loss: 0.1927 - val_accuracy: 0.1597
# Epoch 72/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1912 - accuracy: 0.1570 - val_loss: 0.1925 - val_accuracy: 0.1579
# Epoch 73/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1911 - accuracy: 0.1587 - val_loss: 0.1926 - val_accuracy: 0.1630
# Epoch 74/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1911 - accuracy: 0.1594 - val_loss: 0.1925 - val_accuracy: 0.1591
# Epoch 75/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1911 - accuracy: 0.1608 - val_loss: 0.1926 - val_accuracy: 0.1598
# Epoch 76/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1910 - accuracy: 0.1616 - val_loss: 0.1924 - val_accuracy: 0.1629
# Epoch 77/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1910 - accuracy: 0.1621 - val_loss: 0.1923 - val_accuracy: 0.1641
# Epoch 78/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1909 - accuracy: 0.1617 - val_loss: 0.1924 - val_accuracy: 0.1631
# Epoch 79/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1909 - accuracy: 0.1629 - val_loss: 0.1924 - val_accuracy: 0.1645
# Epoch 80/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1909 - accuracy: 0.1630 - val_loss: 0.1923 - val_accuracy: 0.1636
# Epoch 81/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1908 - accuracy: 0.1637 - val_loss: 0.1922 - val_accuracy: 0.1660
# Epoch 82/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1907 - accuracy: 0.1652 - val_loss: 0.1923 - val_accuracy: 0.1599
# Epoch 83/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1907 - accuracy: 0.1650 - val_loss: 0.1921 - val_accuracy: 0.1660
# Epoch 84/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1907 - accuracy: 0.1658 - val_loss: 0.1921 - val_accuracy: 0.1639
# Epoch 85/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1906 - accuracy: 0.1657 - val_loss: 0.1921 - val_accuracy: 0.1657
# Epoch 86/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1906 - accuracy: 0.1674 - val_loss: 0.1923 - val_accuracy: 0.1703
# Epoch 87/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1905 - accuracy: 0.1686 - val_loss: 0.1921 - val_accuracy: 0.1670
# Epoch 88/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1905 - accuracy: 0.1680 - val_loss: 0.1921 - val_accuracy: 0.1707
# Epoch 89/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1905 - accuracy: 0.1678 - val_loss: 0.1920 - val_accuracy: 0.1716
# Epoch 90/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1905 - accuracy: 0.1698 - val_loss: 0.1920 - val_accuracy: 0.1685
# Epoch 91/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1904 - accuracy: 0.1697 - val_loss: 0.1921 - val_accuracy: 0.1679
# Epoch 92/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1904 - accuracy: 0.1701 - val_loss: 0.1919 - val_accuracy: 0.1660
# Epoch 93/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1904 - accuracy: 0.1708 - val_loss: 0.1920 - val_accuracy: 0.1722
# Epoch 94/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1903 - accuracy: 0.1709 - val_loss: 0.1920 - val_accuracy: 0.1710
# Epoch 95/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1903 - accuracy: 0.1708 - val_loss: 0.1919 - val_accuracy: 0.1737
# Epoch 96/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1903 - accuracy: 0.1715 - val_loss: 0.1920 - val_accuracy: 0.1711
# Epoch 97/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1902 - accuracy: 0.1713 - val_loss: 0.1920 - val_accuracy: 0.1756
# Epoch 98/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1902 - accuracy: 0.1724 - val_loss: 0.1919 - val_accuracy: 0.1738
# Epoch 99/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1902 - accuracy: 0.1722 - val_loss: 0.1918 - val_accuracy: 0.1779
# Epoch 100/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1902 - accuracy: 0.1727 - val_loss: 0.1920 - val_accuracy: 0.1776

# %% [markdown]
# ## 3. Reconstruction and decision
#
# Next, we use our autoencoder to reconstruct all the test images and decide whether they belong to the target class based on the reconstruction error. Here we use the loss (computed by `model.evaluate()`) as the reconstruction error.

# %%
# reconstruct test images
test_images_reconstructed = autoencoder.predict(test_images)

# %%
############################
# specify a threshold loss #
############################
# we suppose that an image should belong to the target class
# if the loss is smaller than this threshold
threshold_loss = 0.3

# randomly plot original and reconstructed images and decisions
nrows = 5
ncols = 3
plt.figure(dpi=100, figsize=(6 * ncols, 2.5 * nrows))
for iplot, itest in enumerate(np.random.choice(len(test_images), nrows * ncols)):
    # plot original and reconstructed images
    subplot_image(test_images[itest], 'Origional', nrows, ncols * 3, iplot * 3)
    subplot_image(test_images_reconstructed[itest], 'Reconstructed', nrows, ncols * 3, iplot * 3 + 1)
    
    # truth
    truth = (test_labels[itest] == target_label)
    # compute loss
    loss = autoencoder.evaluate(np.array([test_images[itest]]), 
                                np.array([test_images[itest]]), verbose=0)[0]
    # prediction
    pred = (loss < threshold_loss)
    # correct or not?
    correct = (truth == pred)
    
    # write information
    subplot_image([[0]], '', nrows, ncols * 3, iplot * 3 + 2)
    textcolor = 'g' if correct else 'r'
    plt.text(-.5, -.3, 'Truth: %s' % string_labels[test_labels[itest]], c='k')
    plt.text(-.5, -.1, 'Loss: %.2f' % loss, c=textcolor)
    plt.text(-.5, .2, 'Prediction:\n%s' % (target_class if pred else 'Non-%s' % target_class), c=textcolor)
    plt.text(-.5, .4, "CORRECT" if correct else 'INCORRECT', c=textcolor, weight='bold')
plt.show()

# %% [markdown]
# **NOTE**:
# It is clear that the autoencoder tends to reshape every input image into the target class. This is why we can use the reconstruction error for decision.

# %% [markdown]
# ## 4. Generate new images
#
# We can also use the autoencoder to generate new images with the following steps:
#
# 1. encode an input image by the encoder;
# 2. change its features in the latent space;
# 3. decode the changed features to generate a new image.

# %% [markdown]
# ### Extract encoder and decoder from autoencoder
#
# We must first extract the encoding and decoding parts from the autoencoder.

# %%
# encoder
encoder = Sequential([
    autoencoder.layers[0],
    autoencoder.layers[1],
    autoencoder.layers[2]],
    name = 'encoder')
encoder.summary()
print('\n\n')

# decoder
decoder = Sequential([
    Input(shape=(nfeature,)),
    autoencoder.layers[-3],
    autoencoder.layers[-2],
    autoencoder.layers[-1]], 
    name='decoder')
decoder.summary()
# Out:
# Model: "encoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 1032
# =================================================================
# Total params: 101,512
# Trainable params: 101,512
# Non-trainable params: 0
# _________________________________________________________________
#
#
#
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 128)               1152
# _________________________________________________________________
# dense_3 (Dense)              (None, 784)               101136
# _________________________________________________________________
# reshape (Reshape)            (None, 28, 28)            0
# =================================================================
# Total params: 102,288
# Trainable params: 102,288
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Encode the images

# %%
# encode training images 
target_train_images_encoded = encoder.predict(target_train_images)

# reconstruct training images
target_train_images_reconstructed = autoencoder.predict(target_train_images)

# print the shapes
print('Shape of original: %s' % str(target_train_images.shape))
print('Shape of encoded: %s' % str(target_train_images_encoded.shape))
print('Shape of reconstructed: %s' % str(target_train_images_reconstructed.shape))
# Out:
# Shape of original: (6000, 28, 28)
# Shape of encoded: (6000, 8)
# Shape of reconstructed: (6000, 28, 28)

# %% [markdown]
# ### Generate new images

# %%
# pick the index of the original image (0~5999)
image_index = 5999

# print original features
encoded_original = target_train_images_encoded[image_index]
print('The %d features in the latent space:' % nfeature)
print(list(encoded_original))
# Out:
# The 8 features in the latent space:
# [0.0, 4.2984133, 7.2035832, 3.7376904, 4.4520845, 0.0, 13.103645, 3.4283166]

# %% [markdown]
# In the following cell, we will implement a UI with slider controls so that we can dynamically change the features and see how the decoded image reacts to such changes.

# %%
# create sliders
sliders = []
argdict = {}
# slider range
smin = encoded_original.min() - (encoded_original.max() - encoded_original.min())
smax = encoded_original.max() + (encoded_original.max() - encoded_original.min())
for i in np.arange(nfeature):
    sliders.append(widgets.FloatSlider(min=smin, max=smax, step=.01, value=encoded_original[i], 
                                       description='Feature %d:' % (i + 1,),
                                       layout=widgets.Layout(width='auto', height='auto')))
    # associate sliders with varaibles passed to the respondent function
    argdict['v%d' % (i + 1)] = sliders[i]
ui = widgets.VBox(sliders)

# the UI-respondent function
# TODO: make argument count consistent with bottleneck size
def respond(v1, v2, v3, v4, v5, v6, v7, v8):
    ##### decoding happens here #####
    # decode
    encoded_modified = np.array([v1, v2, v3, v4, v5, v6, v7, v8])
    decoded_modified = decoder.predict(np.array([encoded_modified]))[0]
    # plot images
    plt.figure(dpi=100, figsize=(10, 3))
    subplot_image(target_train_images[image_index], 'Original', 1, 3, 0)
    subplot_image(target_train_images_reconstructed[image_index], 'Reconstructed original', 1, 3, 1)
    subplot_image(decoded_modified, 'Reconstructed modified', 1, 3, 2)
    plt.show()

# craete UI
out = widgets.interactive_output(respond, argdict)
display(ui, out)
# Out:
# VBox(children=(FloatSlider(value=0.0, description='Feature 1:', layout=Layout(height='auto', width='auto'), ma…
# Output()

# %% [markdown]
# ## Exercises
#
# * The size of the latent space, i.e., `nfeature` in the code, is the most critical network parameter. Try a smaller one (such as 4) and a larger one (such as 16) to see their influences.
#
# * Implement the autoencoder using convolutional layers. For decoding, you can use `Conv2DTranspose` and `UpSampling2D` as the reciprocal layers of `Conv2D` and `MaxPool2D`, respectively.

# %% [markdown]
# ---

# %% [markdown]
# # Unsupervised

# %% [markdown]
# In this part, we will use an autoencoder for unsupervised learning. We have learnt two clustering algorithms in [02_kmeans_GMM.ipynb](02_kmeans_GMM.ipynb), k-means and the Gaussian mixture method. Clustering algorithms are challenged by a large input dimensionality, such as 28 $\times$ 28 for `fashion-mnist`. To reduce the dimensionality, we can first train an autoencoder to encode the images and conduct clustering in the latent space.

# %% [markdown]
# ## 1. Build and train the autoencoder
#
# We use the same architecture as the previous one. The only difference is that we will use all the 10 classes for training.

# %%
########################################
# specify the size of the latent space #
########################################
nfeature_all = 8

# build the network architecture
autoencoder_all = Sequential()

# encoder --------------------------------------------/
autoencoder_all.add(Flatten(input_shape=(28, 28)))
autoencoder_all.add(Dense(128, activation='relu'))
# ----------------------------------------------------/

# bottleneck -----------------------------------------/
autoencoder_all.add(Dense(nfeature_all, activation='relu'))
# ----------------------------------------------------/

# decoder --------------------------------------------/
autoencoder_all.add(Dense(128, activation='relu'))
autoencoder_all.add(Dense(784, activation='sigmoid'))
autoencoder_all.add(Reshape((28, 28)))
# ----------------------------------------------------/

# print summary
autoencoder_all.summary()

# compile the model
autoencoder_all.compile(optimizer='adam', loss='binary_crossentropy', 
                        metrics=['accuracy'])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               100480
# _________________________________________________________________
# dense_5 (Dense)              (None, 8)                 1032
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               1152
# _________________________________________________________________
# dense_7 (Dense)              (None, 784)               101136
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 28, 28)            0
# =================================================================
# Total params: 203,800
# Trainable params: 203,800
# Non-trainable params: 0
# _________________________________________________________________

# %%
# train the model with all the 10 classes
training_history_all = autoencoder_all.fit(train_images, train_images,
                                           epochs=50, batch_size=32,
                                           validation_data=(test_images, test_images))
# Out:
# Epoch 1/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3256 - accuracy: 0.0953 - val_loss: 0.3049 - val_accuracy: 0.1065
# Epoch 2/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2994 - accuracy: 0.1149 - val_loss: 0.2988 - val_accuracy: 0.1218
# Epoch 3/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2955 - accuracy: 0.1219 - val_loss: 0.2965 - val_accuracy: 0.1259
# Epoch 4/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2935 - accuracy: 0.1280 - val_loss: 0.2946 - val_accuracy: 0.1281
# Epoch 5/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2922 - accuracy: 0.1326 - val_loss: 0.2937 - val_accuracy: 0.1374
# Epoch 6/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2913 - accuracy: 0.1362 - val_loss: 0.2930 - val_accuracy: 0.1364
# Epoch 7/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2906 - accuracy: 0.1396 - val_loss: 0.2929 - val_accuracy: 0.1355
# Epoch 8/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2901 - accuracy: 0.1421 - val_loss: 0.2921 - val_accuracy: 0.1416
# Epoch 9/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2896 - accuracy: 0.1443 - val_loss: 0.2919 - val_accuracy: 0.1371
# Epoch 10/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2892 - accuracy: 0.1465 - val_loss: 0.2916 - val_accuracy: 0.1495
# Epoch 11/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2889 - accuracy: 0.1488 - val_loss: 0.2912 - val_accuracy: 0.1513
# Epoch 12/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2885 - accuracy: 0.1497 - val_loss: 0.2910 - val_accuracy: 0.1533
# Epoch 13/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2883 - accuracy: 0.1517 - val_loss: 0.2906 - val_accuracy: 0.1499
# Epoch 14/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2881 - accuracy: 0.1525 - val_loss: 0.2908 - val_accuracy: 0.1541
# Epoch 15/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2879 - accuracy: 0.1538 - val_loss: 0.2902 - val_accuracy: 0.1506
# Epoch 16/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2877 - accuracy: 0.1553 - val_loss: 0.2900 - val_accuracy: 0.1561
# Epoch 17/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2876 - accuracy: 0.1555 - val_loss: 0.2903 - val_accuracy: 0.1564
# Epoch 18/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2874 - accuracy: 0.1564 - val_loss: 0.2899 - val_accuracy: 0.1523
# Epoch 19/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2873 - accuracy: 0.1571 - val_loss: 0.2896 - val_accuracy: 0.1591
# Epoch 20/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2872 - accuracy: 0.1580 - val_loss: 0.2902 - val_accuracy: 0.1578
# Epoch 21/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2871 - accuracy: 0.1593 - val_loss: 0.2894 - val_accuracy: 0.1564
# Epoch 22/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2870 - accuracy: 0.1599 - val_loss: 0.2894 - val_accuracy: 0.1556
# Epoch 23/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2869 - accuracy: 0.1609 - val_loss: 0.2894 - val_accuracy: 0.1623
# Epoch 24/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2868 - accuracy: 0.1611 - val_loss: 0.2894 - val_accuracy: 0.1576
# Epoch 25/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2867 - accuracy: 0.1622 - val_loss: 0.2894 - val_accuracy: 0.1617
# Epoch 26/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2866 - accuracy: 0.1607 - val_loss: 0.2894 - val_accuracy: 0.1622
# Epoch 27/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2865 - accuracy: 0.1622 - val_loss: 0.2895 - val_accuracy: 0.1605
# Epoch 28/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2865 - accuracy: 0.1613 - val_loss: 0.2891 - val_accuracy: 0.1607
# Epoch 29/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2864 - accuracy: 0.1634 - val_loss: 0.2891 - val_accuracy: 0.1583
# Epoch 30/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2863 - accuracy: 0.1636 - val_loss: 0.2889 - val_accuracy: 0.1679
# Epoch 31/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2862 - accuracy: 0.1640 - val_loss: 0.2889 - val_accuracy: 0.1657
# Epoch 32/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2862 - accuracy: 0.1644 - val_loss: 0.2889 - val_accuracy: 0.1668
# Epoch 33/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2861 - accuracy: 0.1641 - val_loss: 0.2888 - val_accuracy: 0.1621
# Epoch 34/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2861 - accuracy: 0.1643 - val_loss: 0.2890 - val_accuracy: 0.1636
# Epoch 35/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2860 - accuracy: 0.1648 - val_loss: 0.2888 - val_accuracy: 0.1602
# Epoch 36/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2859 - accuracy: 0.1649 - val_loss: 0.2886 - val_accuracy: 0.1606
# Epoch 37/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2859 - accuracy: 0.1649 - val_loss: 0.2885 - val_accuracy: 0.1655
# Epoch 38/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2858 - accuracy: 0.1659 - val_loss: 0.2886 - val_accuracy: 0.1652
# Epoch 39/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2858 - accuracy: 0.1660 - val_loss: 0.2885 - val_accuracy: 0.1645
# Epoch 40/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2857 - accuracy: 0.1664 - val_loss: 0.2885 - val_accuracy: 0.1644
# Epoch 41/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2857 - accuracy: 0.1663 - val_loss: 0.2885 - val_accuracy: 0.1614
# Epoch 42/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2856 - accuracy: 0.1668 - val_loss: 0.2886 - val_accuracy: 0.1642
# Epoch 43/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2856 - accuracy: 0.1670 - val_loss: 0.2884 - val_accuracy: 0.1637
# Epoch 44/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2856 - accuracy: 0.1675 - val_loss: 0.2885 - val_accuracy: 0.1642
# Epoch 45/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2855 - accuracy: 0.1674 - val_loss: 0.2884 - val_accuracy: 0.1657
# Epoch 46/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2855 - accuracy: 0.1675 - val_loss: 0.2882 - val_accuracy: 0.1663
# Epoch 47/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2855 - accuracy: 0.1678 - val_loss: 0.2884 - val_accuracy: 0.1626
# Epoch 48/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2854 - accuracy: 0.1682 - val_loss: 0.2883 - val_accuracy: 0.1693
# Epoch 49/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2854 - accuracy: 0.1679 - val_loss: 0.2882 - val_accuracy: 0.1657
# Epoch 50/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2854 - accuracy: 0.1683 - val_loss: 0.2885 - val_accuracy: 0.1737

# %% [markdown]
# ## 2. Encode the images
#
# Extract the encoder from the autoencoder and use it to encode the images

# %%
# extract encoder
encoder_all = Sequential([
    autoencoder_all.layers[0],
    autoencoder_all.layers[1],
    autoencoder_all.layers[2]])
encoder_all.summary()

# encode images
train_images_encoded = encoder_all.predict(train_images)
print('\n* Shape of the encoded images: %s' % str(train_images_encoded.shape))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               100480
# _________________________________________________________________
# dense_5 (Dense)              (None, 8)                 1032
# =================================================================
# Total params: 101,512
# Trainable params: 101,512
# Non-trainable params: 0
# _________________________________________________________________
#
# * Shape of the encoded images: (60000, 8)

# %% [markdown]
# ## 3. Cluster the encoded  images
#
# Now we can use k-means to cluster the encoded images. Note that the number of clusters does not have to be the number of the original classes (10). Here we will use 20 to relax the constraints for k-means.

# %%
# build k-means
n_clusters = 20
kmeans_model = KMeans(n_clusters=n_clusters, max_iter=500)

# train and predict
kmeans_labels = kmeans_model.fit_predict(train_images_encoded)

# print scores
print('Homogeneity score = %.3f' % metrics.homogeneity_score(train_labels, kmeans_labels))
print('Completeness score = %.3f' % metrics.completeness_score(train_labels, kmeans_labels))
print('V-measure score = %.3f' % metrics.v_measure_score(train_labels, kmeans_labels))
# Out:
# Homogeneity score = 0.625
# Completeness score = 0.491
# V-measure score = 0.550

# %% [markdown]
# Further, we can plot a few images in each cluster to get a sense of the quality of clustering:
#
# * It is shown that some similar-looking classes such as "T-shirts", "Shirts", "Coats" and "Pullovers" are not well resolved, which implies that we may need a larger latent space in the autoencoder.
#
# * Also, it is interesting that some classes are clustered into sub-classes, such as "Bags" into the ones with and without handles and the clothes into dark- and light-coloured ones; this explains why we need more than 10 clusters for k-means.

# %%
n_image_per_cluster = 15
for cluster_label in np.arange(n_clusters):
    # get indices of the first n_image_per_cluster in this cluster
    itrains = np.where(kmeans_labels == cluster_label)[0][0:n_image_per_cluster]
    print('\n\nImages in Cluster %d:' % cluster_label)
    fig = plt.figure(dpi=100, figsize=(n_image_per_cluster * 2, n_clusters * 2))
    for iplot, itrain in enumerate(itrains):
        subplot_image(train_images[itrain], string_labels[train_labels[itrain]], 
                      n_clusters, n_image_per_cluster, iplot)
    plt.show()
# Out:
# Images in Cluster 0:
# Images in Cluster 1:
# Images in Cluster 2:
# Images in Cluster 3:
# Images in Cluster 4:
# Images in Cluster 5:
# Images in Cluster 6:
# Images in Cluster 7:
# Images in Cluster 8:
# Images in Cluster 9:
# Images in Cluster 10:
# Images in Cluster 11:
# Images in Cluster 12:
# Images in Cluster 13:
# Images in Cluster 14:
# Images in Cluster 15:
# Images in Cluster 16:
# Images in Cluster 17:
# Images in Cluster 18:
# Images in Cluster 19:

# %% [markdown]
# ### Visualise clustering in the latent space
#
# Finally, we can visualise the clustering results in the latent space. These plots can manifest which features in the latent space are dominating the formation of certain clusters.

# %%
# specify total number of data points to show
show_ndata = 200

# specify the clusters to show
# showing all 20 clusters will make the figures unreadable; just select a few
show_clusters = np.array([1, 2, 3])

# find the data subset
show_data_indices = np.where(np.isin(kmeans_labels, show_clusters))[0][0:show_ndata]

# normalise features to [0, 1]
train_images_encoded_norm = (train_images_encoded - train_images_encoded.min()) / \
                            (train_images_encoded.max() - train_images_encoded.min())
# for better visualisation
train_images_encoded_norm = np.power(train_images_encoded_norm, .5)

# plot
plt.figure(dpi=100, figsize=(15, 15))
iplot = 0
for feature_x in np.arange(nfeature_all):
    for feature_y in np.arange(nfeature_all):
        plt.subplot(nfeature_all, nfeature_all, iplot + 1)
        x = train_images_encoded_norm[show_data_indices, feature_x]
        y = train_images_encoded_norm[show_data_indices, feature_y]
        plt.scatter(x, y, c=kmeans_labels[show_data_indices], s=10, cmap=plt.cm.Paired)
        plt.xticks([])
        plt.yticks([])
        iplot += 1
        if feature_y == 0:
            plt.ylabel('Feature %d' % feature_x, c='k')
        if feature_x == 0:
            plt.gca().xaxis.set_label_position('top') 
            plt.xlabel('Feature %d' % feature_y, c='k')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Exercises
#
# Try to increase the quality of clustering by using
# 1. a larger latent space in the autoencoder
# 2. convolutional layers for encoding and decoding
# 3. GMM for clustering the encodings
