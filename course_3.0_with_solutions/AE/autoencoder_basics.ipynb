# %% [markdown]
# # Autoencoder: the Basics
#
# An autoencoder is a type of artificial neural network used to learn efficient data codings in an unsupervised manner. The aim of an autoencoder is to learn a representation (encoding) for a set of data, typically for dimensionality reduction, by training the network to ignore signal "noise". Along with the reduction side, a reconstructing side is learnt, where the autoencoder tries to generate from the reduced encoding a representation as close as possible to its original input, hence its name. -- from [Wikipedia](https://en.wikipedia.org/wiki/Autoencoder)
#
# An autoencoder can be used for
#
# * feature analysis and dimensionality reduction
# * denoising
# * generating artificial contents (such as faces, musics, scenes)
#
#
#
# ![autoencoder.jpg](https://github.com/stfc-sciml/sciml-workshop-v3/blob/master/course_3.0_with_solutions/markdown_pic/vaee.png?raw=1)
#
#
# In this notebook, we will use an autoencoder in two different ways:
#
# * **Semi-supervised**: train an autoencoder using images from one specific class in the `fashion-mnist` dataset; the trained autoencoder can then be used to decide whether an image belongs to this class based on the reconstruction error; the autoencoder can also be used to generate new images of that class by changing the *features* in the latent space (the bottleneck);
#
# * **Unsupervised**: train an autoencoder using all images in `fashion-mnist` and cluster the images based on the features.

# %%
# tensorflow
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Reshape, Input

# check version
print('Using TensorFlow v%s' % tf.__version__)
acc_str = 'accuracy' if tf.__version__[:2] == '2.' else 'acc'

# k-means
from sklearn.cluster import KMeans
from sklearn import metrics

# helpers
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# widgets for dynamic controls
import ipywidgets as widgets
# Out:
# Using TensorFlow v2.3.1

# %% [markdown]
# ---

# %% [markdown]
# # The Dataset
#
# We start by loading the `fashion-mnist` dataset.

# %%
# load dataset
fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# normalise images
train_images = train_images / 255.0
test_images = test_images / 255.0

# string labels
string_labels = ['T-shirt', 'Trouser', 'Pullover', 'Dress', 'Coat',
                 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# print info
print("Number of training data: %d" % len(train_labels))
print("Number of test data: %d" % len(test_labels))
print("Image pixels: %s" % str(train_images[0].shape))
print("Number of classes: %d" % (np.max(train_labels) + 1))
# Out:
# Number of training data: 60000
# Number of test data: 10000
# Image pixels: (28, 28)
# Number of classes: 10

# %%
# function to plot an image in a subplot
def subplot_image(image, label, nrows=1, ncols=1, iplot=0, label2='', label2_color='r'):
    plt.subplot(nrows, ncols, iplot + 1)
    plt.imshow(image, cmap=plt.cm.binary)
    plt.xlabel(label, c='k', fontsize=12)
    plt.title(label2, c=label2_color, fontsize=12, y=-0.33)
    plt.xticks([])
    plt.yticks([])
    
# ramdomly plot some images and their labels
nrows = 4
ncols = 8
plt.figure(dpi=100, figsize=(ncols * 2, nrows * 2.2))
for iplot, idata in enumerate(np.random.choice(len(train_labels), nrows * ncols)):
    label = "%d: %s" % (train_labels[idata], string_labels[train_labels[idata]])
    subplot_image(train_images[idata], label, nrows, ncols, iplot)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Semi-supervised
#
# In this part, we will train an autoencoder using one specific class in `fashion-mnist`. The autoencoder will use the images from this class as **both the input and the output**. After training the autoencoder, we can feed in any image to decide whether it belongs to this class based on whether it can be well reconstructed by the autoencoder.
#
# Such a strategy can be useful when
#
# * only one or a few classes in the dataset can be reliably labelled;
# * no data in the dataset can be reliably labelled but we can generate synthetic data for some specific classes.
#
# Besides, the autoencoder can be used to generate new images of that class by changing the **features** in the latent space (the bottleneck).

# %% [markdown]
# ## 1. Choose a target class
#
# First, we choose a target class for training and extract the corresponding image subsets.

# %%
###############################
# choose a target class below #
###############################
# 'T-shirt', 'Trouser', 'Pullover', 'Dress', 'Coat',
# 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot'
target_class = 'Sneaker'

# get image subset of the chosen class
target_label = string_labels.index(target_class)
target_train_images = train_images[train_labels == target_label]
target_test_images = test_images[test_labels == target_label]
print('Number of images labelled "%s":' % (target_class,))
print('%d in training data' % (target_train_images.shape[0],))
print('%d in test data' % (target_test_images.shape[0],))
# Out:
# Number of images labelled "Sneaker":
# 6000 in training data
# 1000 in test data

# %% [markdown]
# ## 2. Build and train the autoencoder
#
# As shown in the opening figure, an autoencoder contains three parts:
#
# * the encoder
# * the bottleneck
# * the decoder
#
# Here we use three dense layers to implement these parts. The layers in the encoder and the decoder are reciprocal.

# %% [markdown]
# ### Build the autoencoder

# %%
########################################
# specify the size of the latent space #
########################################
nfeature = 8

# build the network architecture
autoencoder = Sequential()

# encoder --------------------------------------------/
autoencoder.add(Flatten(input_shape=(28, 28)))
autoencoder.add(Dense(128, activation='relu'))
# ----------------------------------------------------/

# bottleneck -----------------------------------------/
autoencoder.add(Dense(nfeature))
# ----------------------------------------------------/

# decoder --------------------------------------------/
autoencoder.add(Dense(128, activation='relu'))
autoencoder.add(Dense(784, activation='sigmoid'))
autoencoder.add(Reshape((28, 28)))
# ----------------------------------------------------/

# print summary
autoencoder.summary()

# compile the model
autoencoder.compile(optimizer='adam', loss='binary_crossentropy', 
                    metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 1032
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               1152
# _________________________________________________________________
# dense_3 (Dense)              (None, 784)               101136
# _________________________________________________________________
# reshape (Reshape)            (None, 28, 28)            0
# =================================================================
# Total params: 203,800
# Trainable params: 203,800
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the autoencoder

# %% [markdown]
# **NOTE**: The input and output images are identical in this case.

# %%
# train the model
training_history = autoencoder.fit(target_train_images, target_train_images,
                                   epochs=100, batch_size=32,
                                   validation_data=(target_test_images, target_test_images))
# Out:
# Epoch 1/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2683 - accuracy: 0.0879 - val_loss: 0.2212 - val_accuracy: 0.0761
# Epoch 2/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.2153 - accuracy: 0.0744 - val_loss: 0.2070 - val_accuracy: 0.0772
# Epoch 3/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.2036 - accuracy: 0.0850 - val_loss: 0.2010 - val_accuracy: 0.0879
# Epoch 4/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1980 - accuracy: 0.0911 - val_loss: 0.1965 - val_accuracy: 0.0912
# Epoch 5/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.1953 - accuracy: 0.0936 - val_loss: 0.1948 - val_accuracy: 0.0986
# Epoch 6/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1939 - accuracy: 0.0957 - val_loss: 0.1939 - val_accuracy: 0.0997
# Epoch 7/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1932 - accuracy: 0.1008 - val_loss: 0.1932 - val_accuracy: 0.1079
# Epoch 8/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1926 - accuracy: 0.1034 - val_loss: 0.1929 - val_accuracy: 0.1104
# Epoch 9/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.1921 - accuracy: 0.1094 - val_loss: 0.1925 - val_accuracy: 0.1085
# Epoch 10/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1917 - accuracy: 0.1120 - val_loss: 0.1922 - val_accuracy: 0.1159
# Epoch 11/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1914 - accuracy: 0.1181 - val_loss: 0.1918 - val_accuracy: 0.1246
# Epoch 12/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.1910 - accuracy: 0.1238 - val_loss: 0.1915 - val_accuracy: 0.1244
# Epoch 13/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.1907 - accuracy: 0.1267 - val_loss: 0.1913 - val_accuracy: 0.1281
# Epoch 14/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1904 - accuracy: 0.1253 - val_loss: 0.1911 - val_accuracy: 0.1247
# Epoch 15/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1901 - accuracy: 0.1274 - val_loss: 0.1908 - val_accuracy: 0.1320
# Epoch 16/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1900 - accuracy: 0.1304 - val_loss: 0.1907 - val_accuracy: 0.1355
# Epoch 17/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1897 - accuracy: 0.1338 - val_loss: 0.1904 - val_accuracy: 0.1305
# Epoch 18/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1895 - accuracy: 0.1340 - val_loss: 0.1904 - val_accuracy: 0.1337
# Epoch 19/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1894 - accuracy: 0.1331 - val_loss: 0.1902 - val_accuracy: 0.1314
# Epoch 20/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1892 - accuracy: 0.1358 - val_loss: 0.1901 - val_accuracy: 0.1321
# Epoch 21/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1891 - accuracy: 0.1365 - val_loss: 0.1900 - val_accuracy: 0.1369
# Epoch 22/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1890 - accuracy: 0.1407 - val_loss: 0.1897 - val_accuracy: 0.1366
# Epoch 23/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1888 - accuracy: 0.1407 - val_loss: 0.1899 - val_accuracy: 0.1423
# Epoch 24/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1887 - accuracy: 0.1431 - val_loss: 0.1896 - val_accuracy: 0.1440
# Epoch 25/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1886 - accuracy: 0.1453 - val_loss: 0.1896 - val_accuracy: 0.1504
# Epoch 26/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1885 - accuracy: 0.1463 - val_loss: 0.1894 - val_accuracy: 0.1449
# Epoch 27/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1884 - accuracy: 0.1470 - val_loss: 0.1895 - val_accuracy: 0.1460
# Epoch 28/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.1883 - accuracy: 0.1497 - val_loss: 0.1894 - val_accuracy: 0.1536
# Epoch 29/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.1883 - accuracy: 0.1512 - val_loss: 0.1893 - val_accuracy: 0.1489
# Epoch 30/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1882 - accuracy: 0.1515 - val_loss: 0.1891 - val_accuracy: 0.1489
# Epoch 31/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.1881 - accuracy: 0.1510 - val_loss: 0.1891 - val_accuracy: 0.1529
# Epoch 32/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1880 - accuracy: 0.1514 - val_loss: 0.1891 - val_accuracy: 0.1498
# Epoch 33/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.1880 - accuracy: 0.1520 - val_loss: 0.1891 - val_accuracy: 0.1500
# Epoch 34/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1878 - accuracy: 0.1513 - val_loss: 0.1891 - val_accuracy: 0.1481
# Epoch 35/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1878 - accuracy: 0.1520 - val_loss: 0.1889 - val_accuracy: 0.1470
# Epoch 36/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1877 - accuracy: 0.1537 - val_loss: 0.1890 - val_accuracy: 0.1529
# Epoch 37/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.1877 - accuracy: 0.1526 - val_loss: 0.1889 - val_accuracy: 0.1497
# Epoch 38/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1876 - accuracy: 0.1524 - val_loss: 0.1888 - val_accuracy: 0.1503
# Epoch 39/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1876 - accuracy: 0.1532 - val_loss: 0.1888 - val_accuracy: 0.1489
# Epoch 40/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1875 - accuracy: 0.1518 - val_loss: 0.1888 - val_accuracy: 0.1478
# Epoch 41/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.1875 - accuracy: 0.1531 - val_loss: 0.1887 - val_accuracy: 0.1484
# Epoch 42/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.1874 - accuracy: 0.1523 - val_loss: 0.1886 - val_accuracy: 0.1461
# Epoch 43/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1874 - accuracy: 0.1513 - val_loss: 0.1887 - val_accuracy: 0.1492
# Epoch 44/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.1873 - accuracy: 0.1531 - val_loss: 0.1887 - val_accuracy: 0.1503
# Epoch 45/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.1873 - accuracy: 0.1525 - val_loss: 0.1886 - val_accuracy: 0.1511
# Epoch 46/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.1872 - accuracy: 0.1534 - val_loss: 0.1885 - val_accuracy: 0.1463
# Epoch 47/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1872 - accuracy: 0.1539 - val_loss: 0.1886 - val_accuracy: 0.1538
# Epoch 48/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.1872 - accuracy: 0.1559 - val_loss: 0.1886 - val_accuracy: 0.1507
# Epoch 49/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1871 - accuracy: 0.1541 - val_loss: 0.1885 - val_accuracy: 0.1530
# Epoch 50/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1871 - accuracy: 0.1519 - val_loss: 0.1886 - val_accuracy: 0.1487
# Epoch 51/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.1871 - accuracy: 0.1537 - val_loss: 0.1884 - val_accuracy: 0.1555
# Epoch 52/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.1870 - accuracy: 0.1550 - val_loss: 0.1883 - val_accuracy: 0.1558
# Epoch 53/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.1870 - accuracy: 0.1556 - val_loss: 0.1886 - val_accuracy: 0.1524
# Epoch 54/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.1869 - accuracy: 0.1527 - val_loss: 0.1885 - val_accuracy: 0.1553
# Epoch 55/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.1869 - accuracy: 0.1563 - val_loss: 0.1884 - val_accuracy: 0.1560
# Epoch 56/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1869 - accuracy: 0.1544 - val_loss: 0.1883 - val_accuracy: 0.1524
# Epoch 57/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1868 - accuracy: 0.1560 - val_loss: 0.1882 - val_accuracy: 0.1564
# Epoch 58/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1868 - accuracy: 0.1547 - val_loss: 0.1884 - val_accuracy: 0.1538
# Epoch 59/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1868 - accuracy: 0.1546 - val_loss: 0.1884 - val_accuracy: 0.1561
# Epoch 60/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1868 - accuracy: 0.1551 - val_loss: 0.1884 - val_accuracy: 0.1573
# Epoch 61/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1868 - accuracy: 0.1563 - val_loss: 0.1882 - val_accuracy: 0.1529
# Epoch 62/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1867 - accuracy: 0.1581 - val_loss: 0.1883 - val_accuracy: 0.1539
# Epoch 63/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1867 - accuracy: 0.1562 - val_loss: 0.1883 - val_accuracy: 0.1513
# Epoch 64/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1867 - accuracy: 0.1554 - val_loss: 0.1882 - val_accuracy: 0.1565
# Epoch 65/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1867 - accuracy: 0.1575 - val_loss: 0.1882 - val_accuracy: 0.1519
# Epoch 66/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1866 - accuracy: 0.1586 - val_loss: 0.1882 - val_accuracy: 0.1570
# Epoch 67/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1866 - accuracy: 0.1594 - val_loss: 0.1883 - val_accuracy: 0.1532
# Epoch 68/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1865 - accuracy: 0.1596 - val_loss: 0.1883 - val_accuracy: 0.1563
# Epoch 69/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1865 - accuracy: 0.1581 - val_loss: 0.1881 - val_accuracy: 0.1548
# Epoch 70/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1865 - accuracy: 0.1591 - val_loss: 0.1882 - val_accuracy: 0.1560
# Epoch 71/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1865 - accuracy: 0.1594 - val_loss: 0.1881 - val_accuracy: 0.1538
# Epoch 72/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1864 - accuracy: 0.1595 - val_loss: 0.1881 - val_accuracy: 0.1538
# Epoch 73/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1864 - accuracy: 0.1612 - val_loss: 0.1881 - val_accuracy: 0.1546
# Epoch 74/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1864 - accuracy: 0.1615 - val_loss: 0.1881 - val_accuracy: 0.1564
# Epoch 75/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1864 - accuracy: 0.1605 - val_loss: 0.1881 - val_accuracy: 0.1551
# Epoch 76/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1864 - accuracy: 0.1585 - val_loss: 0.1881 - val_accuracy: 0.1578
# Epoch 77/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1864 - accuracy: 0.1595 - val_loss: 0.1884 - val_accuracy: 0.1538
# Epoch 78/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1863 - accuracy: 0.1600 - val_loss: 0.1881 - val_accuracy: 0.1573
# Epoch 79/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1863 - accuracy: 0.1602 - val_loss: 0.1880 - val_accuracy: 0.1579
# Epoch 80/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1863 - accuracy: 0.1606 - val_loss: 0.1880 - val_accuracy: 0.1583
# Epoch 81/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1863 - accuracy: 0.1609 - val_loss: 0.1880 - val_accuracy: 0.1611
# Epoch 82/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1862 - accuracy: 0.1622 - val_loss: 0.1881 - val_accuracy: 0.1548
# Epoch 83/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1862 - accuracy: 0.1625 - val_loss: 0.1880 - val_accuracy: 0.1559
# Epoch 84/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1862 - accuracy: 0.1637 - val_loss: 0.1880 - val_accuracy: 0.1640
# Epoch 85/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1862 - accuracy: 0.1636 - val_loss: 0.1880 - val_accuracy: 0.1581
# Epoch 86/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1862 - accuracy: 0.1647 - val_loss: 0.1881 - val_accuracy: 0.1609
# Epoch 87/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1862 - accuracy: 0.1629 - val_loss: 0.1880 - val_accuracy: 0.1601
# Epoch 88/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1861 - accuracy: 0.1638 - val_loss: 0.1881 - val_accuracy: 0.1567
# Epoch 89/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1862 - accuracy: 0.1649 - val_loss: 0.1880 - val_accuracy: 0.1619
# Epoch 90/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1861 - accuracy: 0.1651 - val_loss: 0.1880 - val_accuracy: 0.1620
# Epoch 91/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1861 - accuracy: 0.1643 - val_loss: 0.1880 - val_accuracy: 0.1548
# Epoch 92/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1861 - accuracy: 0.1639 - val_loss: 0.1879 - val_accuracy: 0.1641
# Epoch 93/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1861 - accuracy: 0.1652 - val_loss: 0.1880 - val_accuracy: 0.1626
# Epoch 94/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1860 - accuracy: 0.1663 - val_loss: 0.1880 - val_accuracy: 0.1647
# Epoch 95/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1861 - accuracy: 0.1665 - val_loss: 0.1880 - val_accuracy: 0.1619
# Epoch 96/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1860 - accuracy: 0.1670 - val_loss: 0.1879 - val_accuracy: 0.1644
# Epoch 97/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1860 - accuracy: 0.1652 - val_loss: 0.1880 - val_accuracy: 0.1656
# Epoch 98/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1860 - accuracy: 0.1666 - val_loss: 0.1879 - val_accuracy: 0.1589
# Epoch 99/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1860 - accuracy: 0.1673 - val_loss: 0.1879 - val_accuracy: 0.1631
# Epoch 100/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1860 - accuracy: 0.1676 - val_loss: 0.1880 - val_accuracy: 0.1599

# %% [markdown]
# ## 3. Reconstruction and decision
#
# Next, we use our autoencoder to reconstruct all the test images and decide whether they belong to the target class based on the reconstruction error. Here we use the loss (computed by `model.evaluate()`) as the reconstruction error.

# %%
# reconstruct test images
test_images_reconstructed = autoencoder.predict(test_images)

# %%
############################
# specify a threshold loss #
############################
# we suppose that an image should belong to the target class
# if the loss is smaller than this threshold
threshold_loss = 0.3

# randomly plot original and reconstructed images and decisions
nrows = 5
ncols = 3
plt.figure(dpi=100, figsize=(6 * ncols, 2.5 * nrows))
for iplot, itest in enumerate(np.random.choice(len(test_images), nrows * ncols)):
    # plot original and reconstructed images
    subplot_image(test_images[itest], 'Origional', nrows, ncols * 3, iplot * 3)
    subplot_image(test_images_reconstructed[itest], 'Reconstructed', nrows, ncols * 3, iplot * 3 + 1)
    
    # truth
    truth = (test_labels[itest] == target_label)
    # compute loss
    loss = autoencoder.evaluate(np.array([test_images[itest]]), 
                                np.array([test_images[itest]]), verbose=0)[0]
    # prediction
    pred = (loss < threshold_loss)
    # correct or not?
    correct = (truth == pred)
    
    # write information
    subplot_image([[0]], '', nrows, ncols * 3, iplot * 3 + 2)
    textcolor = 'g' if correct else 'r'
    plt.text(-.5, -.3, 'Truth: %s' % string_labels[test_labels[itest]], c='k')
    plt.text(-.5, -.1, 'Loss: %.2f' % loss, c=textcolor)
    plt.text(-.5, .2, 'Prediction:\n%s' % (target_class if pred else 'Non-%s' % target_class), c=textcolor)
    plt.text(-.5, .4, "CORRECT" if correct else 'INCORRECT', c=textcolor, weight='bold')
plt.show()

# %% [markdown]
# **NOTE**:
# It is clear that the autoencoder tends to reshape every input image into the target class. This is why we can use the reconstruction error for decision.

# %% [markdown]
# ## 4. Generate new images
#
# We can also use the autoencoder to generate new images with the following steps:
#
# 1. encode an input image by the encoder;
# 2. change its features in the latent space;
# 3. decode the changed features to generate a new image.

# %% [markdown]
# ### Extract encoder and decoder from autoencoder
#
# We must first extract the encoding and decoding parts from the autoencoder.

# %%
# encoder
encoder = Sequential([
    autoencoder.layers[0],
    autoencoder.layers[1],
    autoencoder.layers[2]],
    name = 'encoder')
encoder.summary()
print('\n\n')

# decoder
decoder = Sequential([
    Input(shape=(nfeature,)),
    autoencoder.layers[-3],
    autoencoder.layers[-2],
    autoencoder.layers[-1]], 
    name='decoder')
decoder.summary()
# Out:
# Model: "encoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 1032
# =================================================================
# Total params: 101,512
# Trainable params: 101,512
# Non-trainable params: 0
# _________________________________________________________________
#
#
#
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 128)               1152
# _________________________________________________________________
# dense_3 (Dense)              (None, 784)               101136
# _________________________________________________________________
# reshape (Reshape)            (None, 28, 28)            0
# =================================================================
# Total params: 102,288
# Trainable params: 102,288
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Encode the images

# %%
# encode training images 
target_train_images_encoded = encoder.predict(target_train_images)

# reconstruct training images
target_train_images_reconstructed = autoencoder.predict(target_train_images)

# print the shapes
print('Shape of original: %s' % str(target_train_images.shape))
print('Shape of encoded: %s' % str(target_train_images_encoded.shape))
print('Shape of reconstructed: %s' % str(target_train_images_reconstructed.shape))
# Out:
# Shape of original: (6000, 28, 28)
# Shape of encoded: (6000, 8)
# Shape of reconstructed: (6000, 28, 28)

# %% [markdown]
# ### Generate new images

# %%
# pick the index of the original image (0~5999)
image_index = 5999

# print original features
encoded_original = target_train_images_encoded[image_index]
print('The %d features in the latent space:' % nfeature)
print(list(encoded_original))
# Out:
# The 8 features in the latent space:
# [-0.5511011, 1.5643258, -7.080767, 0.71280843, -0.26728338, 0.9362528, 0.86922824, -0.93329734]

# %% [markdown]
# In the following cell, we will implement a UI with slider controls so that we can dynamically change the features and see how the decoded image reacts to such changes.

# %%
# create sliders
sliders = []
argdict = {}
# slider range
smin = encoded_original.min() - (encoded_original.max() - encoded_original.min())
smax = encoded_original.max() + (encoded_original.max() - encoded_original.min())
for i in np.arange(nfeature):
    sliders.append(widgets.FloatSlider(min=smin, max=smax, step=.01, value=encoded_original[i], 
                                       description='Feature %d:' % (i + 1,),
                                       layout=widgets.Layout(width='auto', height='auto')))
    # associate sliders with varaibles passed to the respondent function
    argdict['v%d' % (i + 1)] = sliders[i]
ui = widgets.VBox(sliders)

# the UI-respondent function
def respond(**kwargs):
    ##### decoding happens here #####
    # decode
    encoded_modified = np.array(list(kwargs.values()))
    decoded_modified = decoder.predict(np.array([encoded_modified]))[0]
    # plot images
    plt.figure(dpi=100, figsize=(10, 3))
    subplot_image(target_train_images[image_index], 'Original', 1, 3, 0)
    subplot_image(target_train_images_reconstructed[image_index], 'Reconstructed original', 1, 3, 1)
    subplot_image(decoded_modified, 'Reconstructed modified', 1, 3, 2)
    plt.show()

# craete UI
out = widgets.interactive_output(respond, argdict)
display(ui, out)
# Out:
# VBox(children=(FloatSlider(value=-0.5511010885238647, description='Feature 1:', layout=Layout(height='auto', w…
# Output()

# %% [markdown]
# ## Exercises
#
# * The size of the latent space, i.e., `nfeature` in the code, is the most critical network parameter. Try a smaller one (such as 4) and a larger one (such as 16) to see their influences.
#
# * Implement the autoencoder using convolutional layers. For decoding, you can use `Conv2DTranspose` and `UpSampling2D` as the reciprocal layers of `Conv2D` and `MaxPool2D`, respectively.

# %% [markdown]
# ---

# %% [markdown]
# # Unsupervised

# %% [markdown]
# In this part, we will use an autoencoder for unsupervised learning. We have learnt two clustering algorithms in [clustering_kmeans_GMM.ipynb](../CLASSICAL/clustering_kmeans_GMM.ipynb), k-means and the Gaussian mixture method. Clustering algorithms are challenged by a large input dimensionality, such as 28 $\times$ 28 for `fashion-mnist`. To reduce the dimensionality, we can first train an autoencoder to encode the images and conduct clustering in the latent space.

# %% [markdown]
# ## 1. Build and train the autoencoder
#
# We use the same architecture as the previous one. The only difference is that we will use all the 10 classes for training.

# %%
########################################
# specify the size of the latent space #
########################################
nfeature_all = 8

# build the network architecture
autoencoder_all = Sequential()

# encoder --------------------------------------------/
autoencoder_all.add(Flatten(input_shape=(28, 28)))
autoencoder_all.add(Dense(128, activation='relu'))
# ----------------------------------------------------/

# bottleneck -----------------------------------------/
autoencoder_all.add(Dense(nfeature_all))
# ----------------------------------------------------/

# decoder --------------------------------------------/
autoencoder_all.add(Dense(128, activation='relu'))
autoencoder_all.add(Dense(784, activation='sigmoid'))
autoencoder_all.add(Reshape((28, 28)))
# ----------------------------------------------------/

# print summary
autoencoder_all.summary()

# compile the model
autoencoder_all.compile(optimizer='adam', loss='binary_crossentropy', 
                        metrics=['accuracy'])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               100480
# _________________________________________________________________
# dense_5 (Dense)              (None, 8)                 1032
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               1152
# _________________________________________________________________
# dense_7 (Dense)              (None, 784)               101136
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 28, 28)            0
# =================================================================
# Total params: 203,800
# Trainable params: 203,800
# Non-trainable params: 0
# _________________________________________________________________

# %%
# train the model with all the 10 classes
training_history_all = autoencoder_all.fit(train_images, train_images,
                                           epochs=50, batch_size=32,
                                           validation_data=(test_images, test_images))
# Out:
# Epoch 1/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3160 - accuracy: 0.1034 - val_loss: 0.2992 - val_accuracy: 0.1204
# Epoch 2/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2945 - accuracy: 0.1287 - val_loss: 0.2944 - val_accuracy: 0.1308
# Epoch 3/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2911 - accuracy: 0.1377 - val_loss: 0.2924 - val_accuracy: 0.1418
# Epoch 4/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2893 - accuracy: 0.1423 - val_loss: 0.2912 - val_accuracy: 0.1444
# Epoch 5/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2882 - accuracy: 0.1488 - val_loss: 0.2902 - val_accuracy: 0.1541
# Epoch 6/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2874 - accuracy: 0.1545 - val_loss: 0.2893 - val_accuracy: 0.1543
# Epoch 7/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2868 - accuracy: 0.1571 - val_loss: 0.2893 - val_accuracy: 0.1601
# Epoch 8/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2864 - accuracy: 0.1630 - val_loss: 0.2886 - val_accuracy: 0.1639
# Epoch 9/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2860 - accuracy: 0.1666 - val_loss: 0.2880 - val_accuracy: 0.1709
# Epoch 10/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2857 - accuracy: 0.1688 - val_loss: 0.2881 - val_accuracy: 0.1674
# Epoch 11/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2854 - accuracy: 0.1716 - val_loss: 0.2876 - val_accuracy: 0.1719
# Epoch 12/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2852 - accuracy: 0.1724 - val_loss: 0.2877 - val_accuracy: 0.1734
# Epoch 13/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2850 - accuracy: 0.1748 - val_loss: 0.2873 - val_accuracy: 0.1729
# Epoch 14/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2848 - accuracy: 0.1757 - val_loss: 0.2873 - val_accuracy: 0.1729
# Epoch 15/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2846 - accuracy: 0.1772 - val_loss: 0.2874 - val_accuracy: 0.1732
# Epoch 16/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2845 - accuracy: 0.1767 - val_loss: 0.2869 - val_accuracy: 0.1790
# Epoch 17/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2844 - accuracy: 0.1785 - val_loss: 0.2869 - val_accuracy: 0.1754
# Epoch 18/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2842 - accuracy: 0.1788 - val_loss: 0.2866 - val_accuracy: 0.1775
# Epoch 19/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2841 - accuracy: 0.1782 - val_loss: 0.2868 - val_accuracy: 0.1771
# Epoch 20/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2840 - accuracy: 0.1790 - val_loss: 0.2866 - val_accuracy: 0.1773
# Epoch 21/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2839 - accuracy: 0.1800 - val_loss: 0.2866 - val_accuracy: 0.1785
# Epoch 22/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2838 - accuracy: 0.1804 - val_loss: 0.2863 - val_accuracy: 0.1813
# Epoch 23/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2838 - accuracy: 0.1795 - val_loss: 0.2864 - val_accuracy: 0.1760
# Epoch 24/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2837 - accuracy: 0.1798 - val_loss: 0.2864 - val_accuracy: 0.1776
# Epoch 25/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2836 - accuracy: 0.1794 - val_loss: 0.2861 - val_accuracy: 0.1795
# Epoch 26/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2836 - accuracy: 0.1798 - val_loss: 0.2861 - val_accuracy: 0.1796
# Epoch 27/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2835 - accuracy: 0.1799 - val_loss: 0.2861 - val_accuracy: 0.1787
# Epoch 28/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2834 - accuracy: 0.1813 - val_loss: 0.2862 - val_accuracy: 0.1765
# Epoch 29/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2834 - accuracy: 0.1811 - val_loss: 0.2864 - val_accuracy: 0.1796
# Epoch 30/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2833 - accuracy: 0.1807 - val_loss: 0.2860 - val_accuracy: 0.1820
# Epoch 31/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2833 - accuracy: 0.1809 - val_loss: 0.2860 - val_accuracy: 0.1764
# Epoch 32/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2832 - accuracy: 0.1809 - val_loss: 0.2860 - val_accuracy: 0.1825
# Epoch 33/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2832 - accuracy: 0.1811 - val_loss: 0.2862 - val_accuracy: 0.1776
# Epoch 34/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2831 - accuracy: 0.1806 - val_loss: 0.2859 - val_accuracy: 0.1801
# Epoch 35/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2831 - accuracy: 0.1815 - val_loss: 0.2859 - val_accuracy: 0.1807
# Epoch 36/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2830 - accuracy: 0.1814 - val_loss: 0.2860 - val_accuracy: 0.1829
# Epoch 37/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2830 - accuracy: 0.1816 - val_loss: 0.2857 - val_accuracy: 0.1791
# Epoch 38/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2830 - accuracy: 0.1808 - val_loss: 0.2858 - val_accuracy: 0.1801
# Epoch 39/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2829 - accuracy: 0.1820 - val_loss: 0.2857 - val_accuracy: 0.1792
# Epoch 40/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2829 - accuracy: 0.1819 - val_loss: 0.2863 - val_accuracy: 0.1747
# Epoch 41/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2829 - accuracy: 0.1805 - val_loss: 0.2858 - val_accuracy: 0.1808
# Epoch 42/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2828 - accuracy: 0.1818 - val_loss: 0.2858 - val_accuracy: 0.1784
# Epoch 43/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2828 - accuracy: 0.1821 - val_loss: 0.2856 - val_accuracy: 0.1762
# Epoch 44/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2828 - accuracy: 0.1821 - val_loss: 0.2856 - val_accuracy: 0.1756
# Epoch 45/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2828 - accuracy: 0.1819 - val_loss: 0.2858 - val_accuracy: 0.1812
# Epoch 46/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2827 - accuracy: 0.1823 - val_loss: 0.2856 - val_accuracy: 0.1839
# Epoch 47/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2827 - accuracy: 0.1815 - val_loss: 0.2855 - val_accuracy: 0.1817
# Epoch 48/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2827 - accuracy: 0.1827 - val_loss: 0.2858 - val_accuracy: 0.1792
# Epoch 49/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2827 - accuracy: 0.1824 - val_loss: 0.2856 - val_accuracy: 0.1807
# Epoch 50/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2826 - accuracy: 0.1826 - val_loss: 0.2855 - val_accuracy: 0.1835

# %% [markdown]
# ## 2. Encode the images
#
# Extract the encoder from the autoencoder and use it to encode the images

# %%
# extract encoder
encoder_all = Sequential([
    autoencoder_all.layers[0],
    autoencoder_all.layers[1],
    autoencoder_all.layers[2]])
encoder_all.summary()

# encode images
train_images_encoded = encoder_all.predict(train_images)
print('\n* Shape of the encoded images: %s' % str(train_images_encoded.shape))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               100480
# _________________________________________________________________
# dense_5 (Dense)              (None, 8)                 1032
# =================================================================
# Total params: 101,512
# Trainable params: 101,512
# Non-trainable params: 0
# _________________________________________________________________
#
# * Shape of the encoded images: (60000, 8)

# %% [markdown]
# ## 3. Cluster the encoded  images
#
# Now we can use k-means to cluster the encoded images. Note that the number of clusters does not have to be the number of the original classes (10). Here we will use 20 to relax the constraints for k-means.

# %%
# build k-means
n_clusters = 20
kmeans_model = KMeans(n_clusters=n_clusters, max_iter=500)

# train and predict
kmeans_labels = kmeans_model.fit_predict(train_images_encoded)

# print scores
print('Homogeneity score = %.3f' % metrics.homogeneity_score(train_labels, kmeans_labels))
print('Completeness score = %.3f' % metrics.completeness_score(train_labels, kmeans_labels))
print('V-measure score = %.3f' % metrics.v_measure_score(train_labels, kmeans_labels))
# Out:
# Homogeneity score = 0.641
# Completeness score = 0.507
# V-measure score = 0.566

# %% [markdown]
# Further, we can plot a few images in each cluster to get a sense of the quality of clustering:
#
# * It is shown that some similar-looking classes such as "T-shirts", "Shirts", "Coats" and "Pullovers" are not well resolved, which implies that we may need a larger latent space in the autoencoder.
#
# * Also, it is interesting that some classes are clustered into sub-classes, such as "Bags" into the ones with and without handles and the clothes into dark- and light-coloured ones; this explains why we need more than 10 clusters for k-means.

# %%
n_image_per_cluster = 15
for cluster_label in np.arange(n_clusters):
    # get indices of the first n_image_per_cluster in this cluster
    itrains = np.where(kmeans_labels == cluster_label)[0][0:n_image_per_cluster]
    print('\n\nImages in Cluster %d:' % cluster_label)
    fig = plt.figure(dpi=100, figsize=(n_image_per_cluster * 2, n_clusters * 2))
    for iplot, itrain in enumerate(itrains):
        subplot_image(train_images[itrain], string_labels[train_labels[itrain]], 
                      n_clusters, n_image_per_cluster, iplot)
    plt.show()
# Out:
# Images in Cluster 0:
# Images in Cluster 1:
# Images in Cluster 2:
# Images in Cluster 3:
# Images in Cluster 4:
# Images in Cluster 5:
# Images in Cluster 6:
# Images in Cluster 7:
# Images in Cluster 8:
# Images in Cluster 9:
# Images in Cluster 10:
# Images in Cluster 11:
# Images in Cluster 12:
# Images in Cluster 13:
# Images in Cluster 14:
# Images in Cluster 15:
# Images in Cluster 16:
# Images in Cluster 17:
# Images in Cluster 18:
# Images in Cluster 19:

# %% [markdown]
# ### Visualise clustering in the latent space
#
# Finally, we can visualise the clustering results in the latent space. These plots can manifest which features in the latent space are dominating the formation of certain clusters.

# %%
# specify total number of data points to show
show_ndata = 200

# specify the clusters to show
# showing all 20 clusters will make the figures unreadable; just select a few
show_clusters = np.array([1, 2, 3])

# find the data subset
show_data_indices = np.where(np.isin(kmeans_labels, show_clusters))[0][0:show_ndata]

# normalise features to [0, 1]
train_images_encoded_norm = (train_images_encoded - train_images_encoded.min()) / \
                            (train_images_encoded.max() - train_images_encoded.min())
# for better visualisation
train_images_encoded_norm = np.power(train_images_encoded_norm, .5)

# plot
plt.figure(dpi=100, figsize=(15, 15))
iplot = 0
for feature_x in np.arange(nfeature_all):
    for feature_y in np.arange(nfeature_all):
        plt.subplot(nfeature_all, nfeature_all, iplot + 1)
        x = train_images_encoded_norm[show_data_indices, feature_x]
        y = train_images_encoded_norm[show_data_indices, feature_y]
        plt.scatter(x, y, c=kmeans_labels[show_data_indices], s=10, cmap=plt.cm.Paired)
        plt.xticks([])
        plt.yticks([])
        iplot += 1
        if feature_y == 0:
            plt.ylabel('Feature %d' % feature_x, c='k')
        if feature_x == 0:
            plt.gca().xaxis.set_label_position('top') 
            plt.xlabel('Feature %d' % feature_y, c='k')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## Exercises
#
# Try to increase the quality of clustering by using
# 1. a larger latent space in the autoencoder
# 2. convolutional layers for encoding and decoding
# 3. GMM for clustering the encodings
